# %%
from glob import glob
import pyterrier as pt
from tira.third_party_integrations import ensure_pyterrier_is_loaded

# %%
#ensure_pyterrier_is_loaded()
ds_id = "radboud-validation-20251114-training"
#dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/{ds_id}")
dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/radboud-validation-20251114-training")
topics = dataset.get_topics("title")
qrels = dataset.get_qrels()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/pyterrier/datasets/_core.py:498, in get_dataset(name, **configure_kwargs)
#     497 try:
# --> 498     result = provider.get_dataset(name)
#     499 except KeyError as ex:
#
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/pyterrier/datasets/_irds.py:9, in IRDSDatasetProvider.get_dataset(self, name)
#       8 def get_dataset(self, name) -> pt.datasets.Dataset:
# ----> 9     return IRDSDataset(name)
#
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/pyterrier/datasets/_irds.py:20, in IRDSDataset.__init__(self, irds_id)
#      19 self._irds_id = irds_id
# ---> 20 self._irds_ref = ir_datasets.load(self._irds_id)
#
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/ir_datasets/__init__.py:22, in load(name)
#      21 def load(name):
# ---> 22     return registry[name]
#
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/ir_datasets/util/registry.py:25, in Registry.__getitem__(self, key)
#      24             break
# ---> 25 result = self._registered[key]
#      26 if hasattr(result, 'deprecated'):
#
# KeyError: 'ir-lab-wise-2025/radboud-validation-20251114-training'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       2 ds_id = "radboud-validation-20251114-training"
#       3 #dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/{ds_id}")
# ----> 4 dataset = pt.datasets.get_dataset(f"irds:ir-lab-wise-2025/radboud-validation-20251114-training")
#       5 topics = dataset.get_topics("title")
#       6 qrels = dataset.get_qrels()
#
# File /opt/anaconda3/envs/PbML/lib/python3.12/site-packages/pyterrier/datasets/_core.py:500, in get_dataset(name, **configure_kwargs)
#     498         result = provider.get_dataset(name)
#     499     except KeyError as ex:
# --> 500         raise KeyError(f'Dataset {orig_name!r} not found in provider {provider_name!r}.') from ex
#     502 # Configure
#     503 if isinstance(result, HasConfigure):
#
# KeyError: "Dataset 'irds:ir-lab-wise-2025/radboud-validation-20251114-training' not found in provider 'irds'."

# %%
runs = {}

for run_name in glob(f'output/runs/{ds_id}/*/run.txt.gz'):
    runs[run_name.split('/')[-2]] = pt.io.read_results(run_name)

# %%
pt.Experiment(
    list(runs.values()),
    topics,
    qrels,
    ["ndcg_cut.10"],
    list(runs.keys())
)
